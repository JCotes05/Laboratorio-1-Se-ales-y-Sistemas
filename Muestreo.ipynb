# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
f1 = 20 #Frecuencia de la señal T = 1/10 = 0.1s
f2 = 50
f3 = 70
fs = 10*f3 #Frecuencia de muestreo
Delta = 1/fs #Delta = Ts = 1/fs Tiempo de muestreo

# %%
t = np.arange(0, 0.3+Delta, Delta)
#t1 = np.arange(0, 0.15+Delta, Delta)
#t2 = np.arange(0, 0.06+Delta, Delta)
#t3 = np.arange(0, 0.042+Delta, Delta)

w1 = 2*np.pi*f1 # w = omega
w2 = 2*np.pi*f2
w3 = 2*np.pi*f3
x1_t = np.cos(w1*t)
x2_t = np.sin(w2*t)
x3_t = np.cos(w3*t)

# %%
plt.plot(t, x1_t)
plt.axis([0, 0.15, -1.05, 1.05])
plt.show()
plt.plot(t, x2_t)
plt.axis([0, 0.06, -1.05, 1.05])
plt.show()
plt.plot(t, x3_t)
plt.axis([0, 0.042, -1.05, 1.05])
plt.show()

# %%
import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=t, y=x_t, mode='lines', name='Suma de funciones'))

fig.update_layout(
    title='Suma de funciones',
    xaxis_title='Tiempo (s)',
    yaxis_title='Amplitud',
    showlegend=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plt.plot(t, x_t)
plt.show()
